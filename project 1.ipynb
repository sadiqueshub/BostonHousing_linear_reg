# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Loading the boston housing dataset

# %%
#from sklearn.datasets import load_boston
boston_df = pd.read_csv('HousingData.csv')
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
## converting MEDV to Price
boston_df.rename(columns = {'MEDV':"Price"},inplace = True)
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston_df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# Price       0
# dtype: int64

# %%
boston_df[boston_df.isnull().any(axis = 1)]
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 4     0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# 6     0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311
# 9     0.17004  12.5   7.87   NaN  0.524  6.004  85.9  6.5921    5  311
# 14    0.63796   0.0   8.14   NaN  0.538  6.096  84.5  4.4619    4  307
# 35    0.06417   0.0   5.96   0.0  0.499  5.933  68.2  3.3603    5  279
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 473   4.64689   0.0  18.10   0.0  0.614  6.980  67.6  2.5329   24  666
# 479  14.33370   0.0  18.10   NaN  0.614  6.229  88.0  1.9512   24  666
# 482   5.73116   0.0  18.10   NaN  0.532  7.061  77.0  3.4106   24  666
# 501   0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 4       18.7  396.90    NaN   36.2
# 6       15.2  395.60  12.43   22.9
# ...

# %%
boston_df["CRIM"].fillna(boston_df["CRIM"].mode()[0], inplace=True)
boston_df["ZN"].fillna(boston_df["ZN"].mode()[0], inplace=True)
boston_df["INDUS"].fillna(boston_df["INDUS"].mode()[0], inplace=True)
boston_df["CHAS"].fillna(boston_df["CHAS"].mode()[0], inplace=True)
boston_df["AGE"].fillna(boston_df["AGE"].mode()[0], inplace=True)
boston_df["LSTAT"].fillna(boston_df["LSTAT"].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16340\268325726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   boston_df["CRIM"].fillna(boston_df["CRIM"].mode()[0], inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16340\268325726.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %% [markdown]
# ### doing Exploratory data analysis

# %%
import seaborn as sns

matrix = boston_df.corr()

plt.figure(figsize=(14, 10))  # You can adjust width and height here
sns.heatmap(matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='gray')

plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
arr1 = boston_df.columns
arr1
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Let's assume arr1 is a list of column names you want to plot against the last one
# # For example:
# # arr1 = ['CRIM', 'AGE', 'RM', 'LSTAT', 'Price']  # last column is the Y

# fig, axs = plt.subplots(len(arr1) - 1, 1, figsize=(10, 5 * (len(arr1) - 1)))  # one plot per variable

# # Loop through each predictor (excluding the last one)
# for i, col in enumerate(arr1[:-1]):
#     sns.regplot(x=col, y=arr1[-1], data=boston_df, ax=axs[i])
#     axs[i].set_title(f'{col} vs {arr1[-1]}')

# plt.tight_layout()
# plt.show()

# %%
### separating Target and independent variable
x = boston_df.iloc[:,:-1]
y = boston_df.iloc[:,-1].to_frame()

# %% [markdown]
# #### train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 42)
y_train
# Out:
#      Price
# 5     28.7
# 116   21.2
# 45    19.3
# 16    23.1
# 468   19.1
# ..     ...
# 106   19.5
# 270   21.1
# 348   24.5
# 435   13.4
# 102   18.6
#
# [354 rows x 1 columns]

# %% [markdown]
# ### standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)
x_train
# Out:
# array([[-0.39747041, -0.48778231, -1.33426169, ...,  0.18727079,
#          0.39651419, -0.99529588],
#        [-0.38518012, -0.48778231, -0.19916994, ..., -0.21208981,
#          0.3870674 , -0.83211948],
#        [-0.38036693, -0.48778231, -0.6485677 , ..., -0.16771641,
#          0.42854113, -0.28583327],
#        ...,
#        [-0.39926327,  3.07160832, -1.35890609, ..., -0.56707702,
#          0.35987906, -0.88461972],
#        [ 0.94724354, -0.48778231,  0.97361324, ...,  0.8528718 ,
#         -2.87841346,  1.56728308],
#        [-0.37343952, -0.48778231, -0.40937212, ...,  1.16348561,
#         -3.32828832, -0.22623841]], shape=(354, 13))

# %%
import pickle
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train,y_train)
regression.coef_
# Out:
# array([[-1.06742728e+00,  7.60706151e-01, -2.78491058e-04,
#          9.54781417e-01, -1.69877545e+00,  3.12233591e+00,
#         -4.58990077e-01, -2.93456203e+00,  1.67381056e+00,
#         -1.21768411e+00, -2.04852641e+00,  9.70179248e-01,
#         -3.38018803e+00]])

# %%
## getting coefficients_ and intercepts_
print(regression.coef_)
# Out:
# [[-1.06742728e+00  7.60706151e-01 -2.78491058e-04  9.54781417e-01
#   -1.69877545e+00  3.12233591e+00 -4.58990077e-01 -2.93456203e+00
#    1.67381056e+00 -1.21768411e+00 -2.04852641e+00  9.70179248e-01
#   -3.38018803e+00]]

# %%
print(regression.intercept_)
# Out:
# [23.01581921]

# %% [markdown]
# ### Prediction Time

# %%
pred = regression.predict(x_test).flatten()
pred
# Out:
# array([28.32849616, 36.82345298, 15.29182054, 25.11820521, 18.37155629,
#        22.97235923, 17.35458423, 14.38395786, 22.08058476, 20.68513219,
#        25.30131367, 18.72686374, -6.23631076, 21.75645302, 19.03000978,
#        28.13279183, 19.57350883,  5.60895889, 40.66047954, 17.08966344,
#        27.4645413 , 30.0649789 , 11.46333276, 25.57102455, 17.43353154,
#        15.15992172, 24.16515621, 14.53956388, 22.95369489, 19.38343992,
#        22.22084757, 25.02555971, 24.84912403, 17.29844602, 16.23177153,
#        17.38380872, 30.81489031, 20.11521175, 24.57972816, 25.35763041,
#        14.33944284, 31.67547349, 42.63561092, 17.80472669, 27.18540246,
#        16.48543263, 14.03240092, 26.0131903 , 19.6520384 , 30.18683681,
#        21.26139365, 33.02749607, 15.980824  , 26.06118312, 39.33176995,
#        22.18320942, 18.37489331, 32.78004194, 25.00635972, 13.12213967,
#        22.70861763, 30.87081991, 31.4596482 , 16.38881323, 21.28078445,
# ...

# %%
### scatter plot to see the accuracy of model

plt.scatter(y_test,pred)
plt.show()

# %%
residuals = pred - y_test['Price']
residuals
sns.displot(residuals,kind = "kde")
plt.show()

# %% [markdown]
# ### Accuracy Metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 21.82703096307132
# 3.1481438440641423
# 4.671940813309959

# %% [markdown]
# ### R square and Adjusted R square

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.7070712094736272

# %% [markdown]
# # New Data Prediction

# %%
def func():
    # Get column names (excluding the target column)
    feature_names = boston_df.columns[:-1]
    
    # Create a DataFrame with 1 row and correct column names
    a_df = pd.DataFrame([boston_df.iloc[0].to_numpy()[:-1]], columns=feature_names)
    
    # Now scale and predict
    x = regression.predict(scaler.transform(a_df))
    print(x)
    return scaler.transform(a_df)

# %% [markdown]
# ## pickling the Model File

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickle_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(func())
# Out:
# [[30.18683681]]
# array([[30.18683681]])
